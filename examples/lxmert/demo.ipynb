# %%
#%pip install -r requirements.txt

# %%
from IPython.display import clear_output, Image, display
import PIL.Image
import io
import json
import torch
import numpy as np
from transformers import LxmertForQuestionAnswering, LxmertTokenizer
from modeling_frcnn import GeneralizedRCNN
from processing_image import Preprocess, tensorize
from visualizing_image import SingleImageViz
from inference_lxmert import load_ckp, load_config, load_obj_data, show_image
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# <ipython-input-1-f66bfdd973e3> in <module>
#       5 import torch
#       6 import numpy as np
# ----> 7 from transformers import LxmertForQuestionAnswering, LxmertTokenizer
#       8 from modeling_frcnn import GeneralizedRCNN
#       9 from processing_image import Preprocess, tensorize
#
# ModuleNotFoundError: No module named 'transformers'

# %%
# load test data
raw_img = "test_one.jpg"
test_question = ["what clothing is the man wearing, who is on the horse?"]
img_tensor = tensorize(raw_img)
cfg = load_config()
objids, attrids = load_obj_data()
gqa_answers = json.load(open("gqa_answers.json"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-2-a5d1b7ff8990> in <module>
#       2 raw_img = "test_one.jpg"
#       3 test_question = ["what clothing is the man wearing, who is on the horse?"]
# ----> 4 img_tensor = tensorize(raw_img)
#       5 cfg = load_config()
#       6 objids, attrids = load_obj_data()
#
# NameError: name 'tensorize' is not defined

# %%
# load models and model components
visualizer = SingleImageViz(img_tensor, id2obj=objids, id2attr=attrids)
preprocess = Preprocess(cfg)
frcnn = GeneralizedRCNN(cfg)
frcnn.load_state_dict(load_ckp(), strict=False)
frcnn.eval()
lxmert_tokenizer = LxmertTokenizer.from_pretrained("eltoto1219/lxmert-gqa-untuned")
lxmert = LxmertForQuestionAnswering.from_pretrained("eltoto1219/lxmert-gqa-untuned", num_qa_labels=len(gqa_answers))
lxmert.eval()
# Out:
# Model name 'bert-base-uncased' not found in model shortcut name list (unc-nlp/lxmert-base-uncased). Assuming 'bert-base-uncased' is a path, a model identifier, or url to a directory containing tokenizer files.
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-vocab.txt from cache at /home/eltoto/.cache/torch/transformers/26bc1ad6c0ac742e9b52263248f6d0f00068293b33709fae12320c0e35ccfbbb.542ce4285a40d23a559526243235df47c5f75c197f04f37d1a0c124c32c9a084
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-added_tokens.json from cache at None
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-special_tokens_map.json from cache at None
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-tokenizer_config.json from cache at None
# loading file https://s3.amazonaws.com/models.huggingface.co/bert/bert-base-uncased-tokenizer.json from cache at None
# https://s3.amazonaws.com/models.huggingface.co/bert/eltoto1219/lxmert-gqa-untuned/config.json not found in cache or force_download set to True, downloading to /home/eltoto/.cache/torch/transformers/tmpvjatc8fn
# storing https://s3.amazonaws.com/models.huggingface.co/bert/eltoto1219/lxmert-gqa-untuned/config.json in cache at /home/eltoto/.cache/torch/transformers/01216b1744d0e2cc8a414a56e6f92fa3e1d2ca5272972cbfc36746b7fc56ae17.c52f1b860ba48dc53e0c30615eb1e76c88a6857e16532d77257ba591535197a3
# creating metadata file for /home/eltoto/.cache/torch/transformers/01216b1744d0e2cc8a414a56e6f92fa3e1d2ca5272972cbfc36746b7fc56ae17.c52f1b860ba48dc53e0c30615eb1e76c88a6857e16532d77257ba591535197a3
# loading configuration file https://s3.amazonaws.com/models.huggingface.co/bert/eltoto1219/lxmert-gqa-untuned/config.json from cache at /home/eltoto/.cache/torch/transformers/01216b1744d0e2cc8a414a56e6f92fa3e1d2ca5272972cbfc36746b7fc56ae17.c52f1b860ba48dc53e0c30615eb1e76c88a6857e16532d77257ba591535197a3
# Model config LxmertConfig {
#   "architectures": [
#     "LxmertForQuestionAnswering"
#   ],
#   "attention_probs_dropout_prob": 0.1,
#   "hidden_act": "gelu",
#   "hidden_dropout_prob": 0.1,
#   "hidden_size": 768,
#   "initializer_range": 0.02,
#   "intermediate_size": 3072,
#   "l_layers": 9,
#   "layer_norm_eps": 1e-12,
#   "max_position_embeddings": 512,
#   "model_type": "lxmert",
#   "num_attention_heads": 12,
#   "num_attr_labels": 400,
#   "num_hidden_layers": {
#     "cross_encoder": 5,
#     "language": 9,
#     "vision": 5
#   },
#   "num_object_labels": 1600,
#   "num_qa_labels": 1842,
#   "r_layers": 5,
#   "task_mask_lm": true,
#   "task_matched": true,
#   "task_obj_predict": true,
#   "task_qa": true,
#   "type_vocab_size": 2,
#   "visual_attr_loss": true,
#   "visual_feat_dim": 2048,
#   "visual_feat_loss": true,
#   "visual_loss_normalizer": 6.67,
#   "visual_obj_loss": true,
#   "visual_pos_dim": 4,
#   "vocab_size": 30522,
#   "x_layers": 5
# }
#
# https://cdn.huggingface.co/eltoto1219/lxmert-gqa-untuned/pytorch_model.bin not found in cache or force_download set to True, downloading to /home/eltoto/.cache/torch/transformers/tmp1sk7u8rg
# storing https://cdn.huggingface.co/eltoto1219/lxmert-gqa-untuned/pytorch_model.bin in cache at /home/eltoto/.cache/torch/transformers/e1c906febd68037c36d0d91da6ea3cc33db5c55f9efd64c75a832e30ddd03b18.a94b8300325c7436b6880f24b05118896cc503a68d51a038a8bd94dbafa85bdd
# creating metadata file for /home/eltoto/.cache/torch/transformers/e1c906febd68037c36d0d91da6ea3cc33db5c55f9efd64c75a832e30ddd03b18.a94b8300325c7436b6880f24b05118896cc503a68d51a038a8bd94dbafa85bdd
# loading weights file https://cdn.huggingface.co/eltoto1219/lxmert-gqa-untuned/pytorch_model.bin from cache at /home/eltoto/.cache/torch/transformers/e1c906febd68037c36d0d91da6ea3cc33db5c55f9efd64c75a832e30ddd03b18.a94b8300325c7436b6880f24b05118896cc503a68d51a038a8bd94dbafa85bdd
# All model checkpoint weights were used when initializing LxmertForQuestionAnswering.
#
# All the weights of LxmertForQuestionAnswering were initialized from the model checkpoint at eltoto1219/lxmert-gqa-untuned.
# If your task is similar to the task the model of the checkpoint was trained on, you can already use LxmertForQuestionAnswering for predictions without further training.
# LxmertForQuestionAnswering(
#   (lxmert): LxmertModel(
#     (embeddings): LxmertEmbeddings(
#       (word_embeddings): Embedding(30522, 768, padding_idx=0)
#       (position_embeddings): Embedding(512, 768, padding_idx=0)
#       (token_type_embeddings): Embedding(2, 768, padding_idx=0)
#       (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#     (encoder): LxmertEncoder(
#       (visn_fc): LxmertVisualFeatureEncoder(
#         (visn_fc): Linear(in_features=2048, out_features=768, bias=True)
#         (visn_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (box_fc): Linear(in_features=4, out_features=768, bias=True)
#         (box_layer_norm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#         (dropout): Dropout(p=0.1, inplace=False)
#       )
#       (layer): ModuleList(
#         (0): LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (5): LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (6): LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (7): LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (8): LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (x_layers): ModuleList(
#         (0): LxmertXLayer(
#           (visual_attention): LxmertCrossattLayer(
#             (att): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (lang_self_att): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (visn_self_att): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (lang_inter): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (lang_output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (visn_inter): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (visn_output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): LxmertXLayer(
#           (visual_attention): LxmertCrossattLayer(
#             (att): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (lang_self_att): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (visn_self_att): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (lang_inter): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (lang_output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (visn_inter): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (visn_output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): LxmertXLayer(
#           (visual_attention): LxmertCrossattLayer(
#             (att): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (lang_self_att): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (visn_self_att): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (lang_inter): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (lang_output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (visn_inter): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (visn_output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): LxmertXLayer(
#           (visual_attention): LxmertCrossattLayer(
#             (att): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (lang_self_att): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (visn_self_att): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (lang_inter): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (lang_output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (visn_inter): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (visn_output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): LxmertXLayer(
#           (visual_attention): LxmertCrossattLayer(
#             (att): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (lang_self_att): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (visn_self_att): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (lang_inter): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (lang_output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#           (visn_inter): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (visn_output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#       (r_layers): ModuleList(
#         (0): LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (1): LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (2): LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (3): LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#         (4): LxmertLayer(
#           (attention): LxmertSelfAttentionLayer(
#             (self): LxmertAttention(
#               (query): Linear(in_features=768, out_features=768, bias=True)
#               (key): Linear(in_features=768, out_features=768, bias=True)
#               (value): Linear(in_features=768, out_features=768, bias=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#             (output): LxmertAttOutput(
#               (dense): Linear(in_features=768, out_features=768, bias=True)
#               (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#               (dropout): Dropout(p=0.1, inplace=False)
#             )
#           )
#           (intermediate): LxmertIntermediate(
#             (dense): Linear(in_features=768, out_features=3072, bias=True)
#           )
#           (output): LxmertOutput(
#             (dense): Linear(in_features=3072, out_features=768, bias=True)
#             (LayerNorm): LayerNorm((768,), eps=1e-12, elementwise_affine=True)
#             (dropout): Dropout(p=0.1, inplace=False)
#           )
#         )
#       )
#     )
#     (pooler): LxmertPooler(
#       (dense): Linear(in_features=768, out_features=768, bias=True)
#       (activation): Tanh()
#     )
#   )
#   (answer_head): LxmertVisualAnswerHead(
#     (logit_fc): Sequential(
#       (0): Linear(in_features=768, out_features=1536, bias=True)
#       (1): GeLU()
#       (2): LayerNorm((1536,), eps=1e-12, elementwise_affine=True)
#       (3): Linear(in_features=1536, out_features=1842, bias=True)
#     )
#   )
#   (loss): CrossEntropyLoss()
# )

# %%
# run frcnn
images, sizes, scales_yx = preprocess(img_tensor)
output_dict = frcnn(images, sizes, scales_yx=scales_yx)
output_dict = output_dict[0] # we only want the first image
features = output_dict.pop("roi_features")
boxes = output_dict.pop("boxes")
# add boxes and labels to the image
visualizer.draw_boxes(
    boxes,
    output_dict.pop("obj_ids"),
    output_dict.pop("obj_scores"),
    output_dict.pop("attr_ids"),
    output_dict.pop("attr_scores"),
)

# %%
# visualize output
def showarray(a, fmt='jpeg'):
    a = np.uint8(np.clip(a, 0, 255))
    f = io.BytesIO()
    PIL.Image.fromarray(a).save(f, fmt)
    display(Image(data=f.getvalue()))
showarray(visualizer._get_buffer())

# %%
# run lxmert
inputs = lxmert_tokenizer(
    test_question,
    padding="max_length",
    max_length=20,
    truncation=True,
    return_token_type_ids=True,
    return_attention_mask=True,
    add_special_tokens=True,
)

output = lxmert(
    input_ids=torch.tensor(inputs.input_ids),
    attention_mask=torch.tensor(inputs.attention_mask),
    visual_feats=features.unsqueeze(0),
    visual_pos=boxes.unsqueeze(0),
    token_type_ids=torch.tensor(inputs.token_type_ids),
    return_dict=True,
    output_attentions=False,
)

# %%
# get prediction
logit, pred = output["question_answering_score"].max(-1)
print("Question:", test_question)
print("prediction:", gqa_answers[pred])
print("class ind:", int(pred))
# Out:
# Question: ['what clothing is the man wearing, who is on the horse?']
# prediction: suit
# class ind: 1105
